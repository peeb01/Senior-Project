# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = {
    'Model': ['ANN Normal', 'ANN Class Weight', 'CNN Normal', 'CNN Class Weight',
              'ANN Normal (Planet)', 'CNN Normal (Planet)', 'ANN Class Weight (Planet)', 'CNN Class Weight (Planet)'],
    'F1-Score': [0.11169200677504112, 0.006192012947502486, 0.011326692314379726, 5.3844971867020185e-05,
                 0.018714664419652714, 0.015254338838848833, 0.016390118832910475, 0.006174966107685057],
    'Feature Type': ['Asteroid', 'Asteroid', 'Asteroid', 'Asteroid',
                  'Planet', 'Planet', 'Planet', 'Planet']
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='F1-Score', hue='Feature Type', data=df)
plt.title('Comparison of F1-Score between Models')
plt.xlabel('Model')
plt.ylabel('F1-Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
